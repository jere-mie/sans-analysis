# %%
# place imports here
# this cell failing? Try doing "control-shift-p" then select "restart kernel"
from import_helper import helpers as hp
import matplotlib.pyplot as plt
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
# Out:
# [   array([ 0.44728586, -0.39343281,  0.8032098 ]),
#     array([-0.00913588, -0.77944045, -0.62640971]),
#     array([-0.77931984,  0.00166332,  0.62662415]),
#     array([ 0.70614076, -0.20273523, -0.67842734]),
#     array([-0.03444222,  0.96945209,  0.24285051]),
#     array([ 0.48740687,  0.64789811, -0.58537389]),
#     array([-0.7306691 ,  0.64646833, -0.21954808]),
#     array([0.62411729, 0.4732756 , 0.62168144]),
#     array([-0.5871421 , -0.78801433,  0.18519604]),
#     array([-0.07080867,  0.07208597, -0.99488177])]

# %%
fig = plt.figure()
ax = plt.axes(projection = '3d')
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_zlim([-1, 1])

start = [0,0,0]
for i in domains:
    ax.quiver(0, 0, 0, i[0], i[1], i[2])
ax.view_init(10, 10)

# %%
# lets check different views
vecs = hp.randomDomainCentres(n=10, ad=0.5)    

for i in range(0, 200, 20):
    fig = plt.figure()
    ax = plt.axes(projection = '3d')
    ax.set_xlim([-1, 1])
    ax.set_ylim([-1, 1])
    ax.set_zlim([-1, 1])

    start = [0,0,0]
    for j in vecs:
        ax.quiver(0, 0, 0, j[0], j[1], j[2])
    ax.view_init(i, i)
