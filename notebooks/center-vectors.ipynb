# %%
# place imports here
# this cell failing? Try doing "control-shift-p" then select "restart kernel"
from import_helper import helpers as hp
import matplotlib.pyplot as plt
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
domains = hp.randomDomainCentres(10, 0.5)
pp.pprint(list(domains))
# Out:
# [   array([0.91242294, 0.25431699, 0.32063569]),
#     array([ 0.79604846, -0.58515812, -0.15458598]),
#     array([ 0.22936132,  0.69917714, -0.67715929]),
#     array([-0.94834849,  0.31657025,  0.02045512]),
#     array([-0.37040126, -0.81915113, -0.43794331]),
#     array([-0.16319302,  0.18466757,  0.96915733]),
#     array([ 0.0024471 , -0.72020252,  0.69375958]),
#     array([-0.22159188,  0.94079483,  0.25651924]),
#     array([-0.01925267, -0.12866848, -0.99150076]),
#     array([-0.79135828, -0.48337703,  0.37429762])]

# %%
fig = plt.figure()
ax = plt.axes(projection = '3d')
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_zlim([-1, 1])

start = [0,0,0]
for i in domains:
    ax.quiver(0, 0, 0, i[0], i[1], i[2])
ax.view_init(10, 10)
