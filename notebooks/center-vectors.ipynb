# %%
# place imports here
# this cell failing? Try doing "control-shift-p" then select "restart kernel"
from import_helper import helpers as hp
import matplotlib.pyplot as plt
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
domains = hp.randomDomainCentres(10, 0.5)
pp.pprint(list(domains))
# Out:
# [   array([0.17309753, 0.65991896, 0.7311253 ]),
#     array([-0.00194526, -0.8777    , -0.47920656]),
#     array([ 0.99786829,  0.06338587, -0.01552786]),
#     array([-0.06786238, -0.51286198,  0.8557846 ]),
#     array([ 0.14381174,  0.96856157, -0.20299426]),
#     array([-0.79238114,  0.3553261 ,  0.49585834]),
#     array([-0.29624272,  0.06208895, -0.95309245]),
#     array([-0.94267221, -0.07697822, -0.32472059]),
#     array([-0.61489181, -0.77601747,  0.14037432]),
#     array([ 0.62048872, -0.20855716, -0.75597464])]

# %%
fig = plt.figure()
ax = plt.axes(projection = '3d')
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_zlim([-1, 1])

start = [0,0,0]
for i in domains:
    ax.quiver(0, 0, 0, i[0], i[1], i[2])
ax.view_init(10, 10)

# %%
# lets check different views
vecs = hp.randomDomainCentres(n=10, ad=0.5)    

for i in range(0, 200, 20):
    fig = plt.figure()
    ax = plt.axes(projection = '3d')
    ax.set_xlim([-1, 1])
    ax.set_ylim([-1, 1])
    ax.set_zlim([-1, 1])

    start = [0,0,0]
    for j in vecs:
        ax.quiver(0, 0, 0, j[0], j[1], j[2])
    ax.view_init(i, i)
