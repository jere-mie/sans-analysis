# %%
# place imports here
# this cell failing? Try doing "control-shift-p" then select "restart kernel"
from import_helper import helpers as hp
import matplotlib.pyplot as plt
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
domains = hp.randomDomainCentres(4, 0.5)
pp.pprint(list(domains))
# Out:
# [   array([-0.68716519,  0.43913554,  0.57876073]),
#     array([-0.52709453, -0.57503095, -0.62570821]),
#     array([ 0.41237576, -0.42678156,  0.80486256]),
#     array([ 0.45505288,  0.34132972, -0.82244811])]

# %%
fig = plt.figure()
ax = plt.axes(projection = '3d')
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_zlim([-1, 1])

start = [0,0,0]
for i in domains:
    ax.quiver(0, 0, 0, i[0], i[1], i[2])
ax.view_init(10, 10)
